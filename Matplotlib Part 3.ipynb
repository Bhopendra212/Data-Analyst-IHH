# %% [markdown]
# # Histogram plot graph

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x=np.random.randint(10,60,(50))
print(x)
# Out:
# [45 57 56 56 54 43 17 53 13 38 22 27 23 16 32 58 32 17 11 23 29 48 21 26
#  54 33 46 22 42 38 49 15 49 40 21 13 39 51 11 27 54 42 53 12 54 13 38 53
#  21 26]

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no)
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no)
plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='y',linewidth=2)

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

l=[10,20,30,40,50,60]
plt.hist(no,color='g',edgecolor='y',linewidth=2,bins=l)

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

l=[10,20,30,40,50,60]
plt.hist(no,'auto',(0,200),edgecolor='y',linewidth=2)

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

l=[10,20,30,40,50,60]
plt.hist(no,'auto',(0,100),edgecolor='y',linewidth=2)

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='y',linewidth=2,cumulative=-1)

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='y',linewidth=2,cumulative=-1,bottom=10)

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='y',linewidth=2,cumulative=-1,bottom=20)

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='y',linewidth=2,align='right')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='y',linewidth=2,align='left')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='y',linewidth=2,align='mid')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='r',linewidth=2,histtype='step')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='y',edgecolor='r',linewidth=2,histtype='stepfilled')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='y',edgecolor='r',linewidth=2,histtype='barstacked')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='y',edgecolor='r',linewidth=2,histtype='barstacked',orientation='horizontal')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='y',edgecolor='r',linewidth=2,histtype='barstacked',orientation='vertical')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='y',edgecolor='r',linewidth=2,histtype='barstacked',rwidth=0.6)

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='y',edgecolor='r',linewidth=2,histtype='barstacked',log=True)

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='y',edgecolor='r',linewidth=2,label='code')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.legend()
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='r',linewidth=2,label='code')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.legend()
plt.axvline(45,color='magenta')
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='r',linewidth=2,label='code')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.legend()
plt.axvline(45,color='magenta',label='separate')
plt.legend()
plt.show()

# %%
no=[45,5,7, 56, 56, 54, 43, 17, 53, 13, 38, 22, 27, 23, 16, 32, 58, 32, 17, 11, 23, 29, 48, 21, 26,
 54, 33, 46, 22, 42, 38, 49, 15, 49, 40, 21, 13, 39, 51, 11, 27, 54,42, 53, 12, 54, 13, 38, 53,
 21, 26,]

plt.hist(no,color='g',edgecolor='r',linewidth=2,label='code')

plt.title('Record')
plt.xlabel('python')
plt.ylabel('number')
plt.legend()
plt.axvline(45,color='magenta',label='separate')
plt.legend()
plt.grid()
plt.show()
