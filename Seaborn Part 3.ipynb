# %% [markdown]
# # Voilin plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x='day',y='total_bill',data=df)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x='day',y='total_bill',data=df,hue='time')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x='day',y='total_bill',data=df,hue='time',linewidth=1)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x='day',y='total_bill',data=df,palette='jet_r')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x='day',y='total_bill',data=df,palette='turbo_r')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x='time',y='total_bill',data=df,order=['Dinner','Lunch'],color='r',saturation=0.5)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x='day',y='total_bill',data=df,hue='sex',split=True)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(y='day',x='total_bill',data=df,hue='sex',split=True)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x='time',y='total_bill',data=df,order=['Dinner','Lunch'],inner='quartz')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x='time',y='total_bill',data=df,order=['Dinner','Lunch'],inner='box')
plt.show()

# %%
sns.violinplot(x='time',y='total_bill',data=df,order=['Dinner','Lunch'],inner='point')
plt.show()

# %%
sns.violinplot(x='time',y='total_bill',data=df,order=['Dinner','Lunch'],inner='stick')
plt.show()

# %%
sns.violinplot(x=df['total_bill'])
plt.show()

# %%
sns.violinplot(y=df['total_bill'])
plt.show()

# %% [markdown]
# # Pair plot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(df)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
sns.pairplot(df,hue='sex')
plt.show()

# %%
sns.pairplot(df,hue='sex',vars=['total_bill','tip'])
plt.show()

# %%
sns.pairplot(df,hue='sex',vars=['total_bill','tip'],hue_order=['Female','Male'])
plt.show()

# %%
sns.pairplot(df,hue='sex',vars=['total_bill','tip'],hue_order=['Female','Male'],palette='gist_rainbow_r')
plt.show()

# %%
sns.pairplot(df,hue='sex',x_vars=['total_bill','tip'],hue_order=['Female','Male'],palette='gist_rainbow_r')
plt.show()

# %%
sns.pairplot(df,hue='sex',y_vars=['total_bill','tip'],hue_order=['Female','Male'],palette='gist_rainbow_r')
plt.show()

# %%
sns.pairplot(df,hue='sex',y_vars=['total_bill','tip'],hue_order=['Female','Male'],palette='gist_rainbow_r',kind='reg')
plt.show()

# %%
sns.pairplot(df,hue='sex',y_vars=['total_bill','tip'],hue_order=['Female','Male'],palette='gist_rainbow_r',kind='scatter')
plt.show()

# %%
sns.pairplot(df,hue='sex',y_vars=['total_bill','tip'],hue_order=['Female','Male'],palette='gist_rainbow_r',kind='hist')
plt.show()

# %%
sns.pairplot(df,hue='sex',y_vars=['total_bill','tip'],hue_order=['Female','Male'],palette='gist_rainbow_r',kind='kde')
plt.show()

# %%
sns.pairplot(df,hue='sex',hue_order=['Female','Male'],diag_kind='hist',kind='kde',palette='gist_rainbow_r')
plt.show()

# %% [markdown]
# # strip plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
sns.stripplot(x='day',y='total_bill',data=df)
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=df,hue='sex')
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=df,hue='sex',palette='afmhot_r')
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=df,hue='sex',palette='afmhot_r',linewidth=1)
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=df,hue='sex',palette='afmhot_r',linewidth=1,edgecolor='g')
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=df,hue='sex',palette='afmhot_r',linewidth=1,edgecolor='g',jitter=2)
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=df,hue='sex',palette='afmhot_r',linewidth=1,edgecolor='g',size=10)
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=df,hue='sex',palette='afmhot_r',linewidth=1,edgecolor='g',marker='<')
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=df,hue='sex',palette='afmhot_r',linewidth=1,edgecolor='g',marker='<',alpha=0.5)
plt.show()

# %%
sns.stripplot(x=df['total_bill'])
plt.show()

# %%
sns.stripplot(y=df['total_bill'])
plt.show()

# %% [markdown]
# # Box plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style='whitegrid')
sns.boxplot(x='day',y='total_bill',data=df,hue='time',color='g')
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x='day',y='total_bill',data=df,hue='sex',color='g',order=['Fri','Sun','Thur','Sat'])
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x='day',y='total_bill',data=df,hue='sex',color='g',order=['Fri','Sun','Thur','Sat'],showmeans=True)
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x='day',y='total_bill',data=df,hue='sex',color='y',order=['Fri','Sun','Thur','Sat'],showmeans=True)
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x='day',y='total_bill',data=df,hue='sex',color='y',order=['Fri','Sun','Thur','Sat'],showmeans=True,meanprops={'marker':'+','markeredgecolor':'b'})
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x='day',y='total_bill',data=df,hue='sex',color='y',order=['Fri','Sun','Thur','Sat'],
            showmeans=True,meanprops={'marker':'+','markeredgecolor':'b'},palette='cubehelix_r')
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(data=df,color='y',showmeans=True,meanprops={'marker':'+','markeredgecolor':'b'},palette='cubehelix_r')
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(data=df,color='y',showmeans=True,meanprops={'marker':'+','markeredgecolor':'b'},palette='cubehelix_r',orient='h')
plt.show()

# %%
sns.boxplot(y=df['total_bill'])
plt.show()
